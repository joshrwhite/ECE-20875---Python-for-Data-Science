# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
from problem1 import*

data = getData('distA.csv')
stats.probplot(data, dist='laplace', plot=plt)
plt.show()
# I believe that this data set was generated with a Laplace Distribution.  This is further explained below.

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
from problem1 import*

data = getData('distA.csv')
js = sweepCross(data, min(data), max(data), 1, 250)
_, bin_num = findMin(js)
plt.hist(data, bins=bin_num)
plt.ylabel('Frequency')
plt.show()

# Not only does the Probability Plot appear to line up with the data, but also
# the histogram representation appears to model a Laplace Distribution very well.
# 
# The only points of debate are the variety in the data toward the upper and lower ends,
# but I believe this does not discredit the validity of the probplot or histogram.

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
from problem1 import*

data = getData('distB.csv')
stats.probplot(data, dist = 'expon', plot=plt)
plt.show()
# I believe that this data set was generated with an Exponential Distribution.  This is further explained below.

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
from problem1 import*

data = getData('distB.csv')
js = sweepCross(data, min(data), max(data), 1, 250)
_, bin_num = findMin(js)
plt.hist(data, bins=bin_num)
plt.ylabel('Frequency')
plt.show()

# The Probability Plot lines up decently well with the data, but more importantly
# the histogram representation perfectly models a Laplace Distribution.

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
from problem1 import*

data = getData('distC.csv')
stats.probplot(data, dist = 'norm', plot=plt)
plt.show()
# I believe that this data set was generated with a Normal Distribution.  This is further explained below.

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
from helper import *
from problem1 import*

data = getData('distC.csv')
js = sweepCross(data, min(data), max(data), 1, 250)
_, bin_num = findMin(js)
plt.hist(data, bins=bin_num)
plt.ylabel('Frequency')
plt.show()

# The Probability Plot almost perfectly lines up with the data.  Also
# the histogram representation appears to model a Laplace Distribution well.
